# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#载入必要的库" data-toc-modified-id="载入必要的库-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>载入必要的库</a></div><div class="lev1 toc-item"><a href="#机器学习框架" data-toc-modified-id="机器学习框架-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>机器学习框架</a></div><div class="lev1 toc-item"><a href="#初识数据集" data-toc-modified-id="初识数据集-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>初识数据集</a></div><div class="lev1 toc-item"><a href="#探索性数据分析" data-toc-modified-id="探索性数据分析-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>探索性数据分析</a></div><div class="lev2 toc-item"><a href="#相关系数矩阵" data-toc-modified-id="相关系数矩阵-41"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>相关系数矩阵</a></div><div class="lev2 toc-item"><a href="#单变量分析" data-toc-modified-id="单变量分析-42"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>单变量分析</a></div><div class="lev3 toc-item"><a href="#SalePrice" data-toc-modified-id="SalePrice-421"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span><code>SalePrice</code></a></div><div class="lev3 toc-item"><a href="#其他变量" data-toc-modified-id="其他变量-422"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>其他变量</a></div><div class="lev2 toc-item"><a href="#双变量分析" data-toc-modified-id="双变量分析-43"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>双变量分析</a></div><div class="lev3 toc-item"><a href="#连续型变量" data-toc-modified-id="连续型变量-431"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>连续型变量</a></div><div class="lev3 toc-item"><a href="#离散型变量" data-toc-modified-id="离散型变量-432"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>离散型变量</a></div><div class="lev1 toc-item"><a href="#特征工程" data-toc-modified-id="特征工程-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>特征工程</a></div><div class="lev2 toc-item"><a href="#异常值" data-toc-modified-id="异常值-51"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>异常值</a></div><div class="lev2 toc-item"><a href="#对房屋价格进行log变换" data-toc-modified-id="对房屋价格进行log变换-52"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>对房屋价格进行log变换</a></div><div class="lev2 toc-item"><a href="#缺失值" data-toc-modified-id="缺失值-53"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>缺失值</a></div><div class="lev2 toc-item"><a href="#合并训练集和测试集" data-toc-modified-id="合并训练集和测试集-54"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>合并训练集和测试集</a></div><div class="lev2 toc-item"><a href="#对有序的离散型变量进行编码" data-toc-modified-id="对有序的离散型变量进行编码-55"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>对有序的离散型变量进行编码</a></div><div class="lev2 toc-item"><a href="#房屋总面积变量" data-toc-modified-id="房屋总面积变量-56"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>房屋总面积变量</a></div><div class="lev2 toc-item"><a href="#Box-Cox-变换" data-toc-modified-id="Box-Cox-变换-57"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Box-Cox 变换</a></div><div class="lev2 toc-item"><a href="#对无序的离散型变量进行独热编码" data-toc-modified-id="对无序的离散型变量进行独热编码-58"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>对无序的离散型变量进行独热编码</a></div><div class="lev2 toc-item"><a href="#分离训练集和测试集" data-toc-modified-id="分离训练集和测试集-59"><span class="toc-item-num">5.9&nbsp;&nbsp;</span>分离训练集和测试集</a></div><div class="lev1 toc-item"><a href="#建模" data-toc-modified-id="建模-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>建模</a></div><div class="lev2 toc-item"><a href="#交叉验证函数" data-toc-modified-id="交叉验证函数-61"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>交叉验证函数</a></div><div class="lev2 toc-item"><a href="#基模型" data-toc-modified-id="基模型-62"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>基模型</a></div><div class="lev1 toc-item"><a href="#模型融合" data-toc-modified-id="模型融合-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>模型融合</a></div><div class="lev2 toc-item"><a href="#简单平均融合" data-toc-modified-id="简单平均融合-71"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>简单平均融合</a></div><div class="lev2 toc-item"><a href="#堆叠模型" data-toc-modified-id="堆叠模型-72"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>堆叠模型</a></div><div class="lev2 toc-item"><a href="#加权平均融合" data-toc-modified-id="加权平均融合-73"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>加权平均融合</a></div>

# %% [markdown]
# # 载入必要的库

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
from scipy.stats import norm, skew 
from scipy.special import boxcox1p

# %%
# %matplotlib inline

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
mpl.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# # 机器学习框架

# %% [markdown]
# ![](https://raw.githubusercontent.com/blueliberty/Kaggle/master/Tutorial/abhishek_2.png)

# %% [markdown]
# # 初识数据集

# %%
train = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')

# %%
print("训练集的数据维度是 : {} ".format(train.shape))
print("测试集的数据维度是 : {} ".format(test.shape))
# Out:
# 训练集的数据维度是 : (1460, 81)
# 测试集的数据维度是 : (1459, 80)

# %%
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %% [markdown]
# # 探索性数据分析

# %% [markdown]
# ## 相关系数矩阵
# + `TotalBsmtSF` 和 `1stFlrSF` 变量的相关系数很高
# + `Garage` 前缀的变量相关系数很高

# %%
corrmat = train.corr()
f, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(corrmat, vmax=1, square=True);

# %% [markdown]
# 选取与 `SalePrice` 相关系数最高的10个变量，做相关系数矩阵
# + `SalePrice` 与 `OverallQual`、`GrLivArea`、`TotalBsmtSF`、`GarageArea`等体现房屋品质和面积的变量，有很强的相关性
# + `GarageCars`、`GarageArea`等与车库相关的变量，相互之间有很强的相关性
# + `TotalBsmtSF` 与 `1stFloor` 有很强的相关性（地下室面积与1楼面积）
# + `TotRmsAbvGrd` 与 `GrLivArea` 有很强的相关性（房间数量和总居住面积）

# %%
k = 11
cols = corrmat.nlargest(k, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(train[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, 
yticklabels=cols.values, xticklabels=cols.values)
plt.show();

# %% [markdown]
# ## 单变量分析

# %% [markdown]
# ### `SalePrice`
# 通过直方图、核密度图、QQ图，检验 `SalePrice` 是否服从正态分布

# %%
sns.distplot(train['SalePrice'] , fit=norm)

(mu, sigma) = norm.fit(train['SalePrice'])

plt.legend(['正态分布 ($\mu=$ {:.2f}  $\sigma=$ {:.2f} )'.format(mu, sigma)], loc='best')
plt.ylabel('Frequency')
plt.title('SalePrice 单变量分布', fontsize=18);

# %%
fig = plt.figure()
res = stats.probplot(train['SalePrice'], plot=plt)
plt.show()

# %% [markdown]
# `SalePrice` 变量右偏，对其做log1p转换，使之更加接近正态分布

# %%
train["SalePrice"] = np.log1p(train["SalePrice"])

sns.distplot(train['SalePrice'] , fit=norm)

(mu, sigma) = norm.fit(train['SalePrice'])

plt.legend(['正态分布 ($\mu=$ {:.2f}  $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='best')
plt.ylabel('Frequency')
plt.title('SalePrice 单变量分布', fontsize=18);

# %%
fig = plt.figure()
res = stats.probplot(train['SalePrice'], plot=plt)
plt.show()

# %% [markdown]
# ### 其他变量

# %% [markdown]
# 计算所有连续型变量的偏度。可以发现，绝大多数变量的偏度都比较高，不符合正态分布，后续需要进行转换，使变量更接近正态分布。

# %%
numeric_feats = train.dtypes[(train.dtypes != "object") & (train.columns != 'SalePrice')].index

skewness = train[numeric_feats].apply(lambda x: skew(x.dropna())).sort_values(ascending=False)

skewness = pd.DataFrame({'Skew': skewness})

# skewness.head(10)

f, ax = plt.subplots(figsize=(15, 12))
plt.xticks(rotation='90')
sns.barplot(x=skewness.index, y=skewness['Skew'])
plt.xlabel('变量名', fontsize=15)
plt.ylabel('偏度', fontsize=15)
plt.title('各变量的偏度', fontsize=18);

# %% [markdown]
# ## 双变量分析
# + 通过散点图了解单变量的分布情况、两变量的相互关系
#     + `SalePrice` 等变量都是偏态分布，在建模前需要进行转换（log、box-cox变换）
#     + `TotalBsmtSF`和`GrLiveArea`的散点集中在对角线下方，反映了房屋的地上面积一定大于地下面积

# %%
sns.set()
cols = ['SalePrice', 'OverallQual', 'GrLivArea','GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
sns.pairplot(train[cols], size = 2.5)
plt.show();

# %% [markdown]
# ### 连续型变量

# %% [markdown]
# + `GrLivArea` 总居住面积
#     + `SalePrice` 与 `GrLivArea` 呈正相关关系
#     + 存在2个离群点，后续需要考虑删除

# %%
var = 'GrLivArea'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));

# %% [markdown]
# + `TotalBsmtSF` 地下室面积
#     + `SalePrice` 与 `TotalBsmtSF` 呈正相关关系
#     + `TotalBsmtSF` 为0（没有地下室）的房屋，价格总体上都偏低
#     + 存在1个离群点，后续需要考虑删除

# %%
var = 'TotalBsmtSF'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));

# %% [markdown]
# ### 离散型变量

# %% [markdown]
# + `OverallQual` 房屋总体质量
#     + `SalePrice` 与 `OverallQual` 呈正相关关系

# %%
var = 'OverallQual'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %% [markdown]
# + `GarageCars` 房屋总体质量
#     + `SalePrice` 与 `GarageCars` 总体上呈正相关关系
#     + `GarageCars` 为4时，`SalePrice` 有意外的下降

# %%
var = 'GarageCars'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="SalePrice", data=data)
fig.axis(ymin=0, ymax=800000);

# %% [markdown]
# # 特征工程

# %%
train = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')

# %% [markdown]
# ## 异常值

# %% [markdown]
# 存在2个异常值：总居住面积很大，房屋价格很小

# %%
var = 'GrLivArea'
data = pd.concat([train['SalePrice'], train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));

# %% [markdown]
# 删除异常值

# %%
train = train.drop(train[(train['GrLivArea']>4000) & (train['SalePrice']<300000)].index)

fig, ax = plt.subplots()
ax.scatter(train['GrLivArea'], train['SalePrice'])
plt.ylabel('SalePrice', fontsize=13)
plt.xlabel('GrLivArea', fontsize=13)
plt.show();

# %% [markdown]
# ## 对房屋价格进行log变换

# %%
train["SalePrice"] = np.log1p(train["SalePrice"])

# %% [markdown]
# ## 缺失值

# %%
train_na = (train.isnull().sum() / len(train)) * 100
train_na = train_na.drop(train_na[train_na == 0].index).sort_values(ascending=False)[:30]
missing_data = pd.DataFrame({'Missing Ratio' :train_na})
# missing_data.head(20)

f, ax = plt.subplots(figsize=(15, 12))
plt.xticks(rotation='90')
sns.barplot(x=train_na.index, y=train_na)
plt.xlabel('变量名', fontsize=15)
plt.ylabel('缺失值比例', fontsize=15)
plt.title('各变量的缺失值比例', fontsize=18);

# %% [markdown]
# 根据文档中的变量描述，对缺失值进行填充

# %% [markdown]
# + 变量取值为 `NA` ，表示房屋不具备该项属性：用  `'None'` （字符型变量） 或 `0` （数值型变量） 进行填充

# %%
cols_na_none = ['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu',
                'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
                'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
                'MasVnrType', 'MSSubClass']

cols_na_0 = ['GarageYrBlt', 'GarageArea', 'GarageCars',
             'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath',
             'MasVnrArea']

for c in cols_na_none:
    train[c] = train[c].fillna("None")

for c in cols_na_0:
    train[c] = train[c].fillna(0)
    
for c in cols_na_none:
    test[c] = test[c].fillna("None")

for c in cols_na_0:
    test[c] = test[c].fillna(0)

# %% [markdown]
# + 使用分组内的中位数进行填充
# LotFrontage: Linear feet of street connected to property
# 在同一个 `Neighborhood` 中 `LotFrontage` 的取值应该比较接近，所以选择组内中位数进行填充

# %%
train["LotFrontage"] = train.groupby("Neighborhood")["LotFrontage"].transform(lambda x: x.fillna(x.median()))

test["LotFrontage"] = test.groupby("Neighborhood")["LotFrontage"].transform(lambda x: x.fillna(x.median()))

# %% [markdown]
# + 缺失值代表典型值：使用 `'Typical'` 进行填充

# %%
train["Functional"].unique()
# Out:
# array(['Typ', 'Min1', 'Maj1', 'Min2', 'Mod', 'Maj2', 'Sev'], dtype=object)

# %%
train["Functional"] = train["Functional"].fillna("Typ")

test["Functional"] = test["Functional"].fillna("Typ")

# %% [markdown]
# + 使用众数进行填充

# %%
cols_na_mode = ['MSZoning', 'Electrical', 'KitchenQual', 'Exterior1st', 'Exterior2nd', 'SaleType']

for c in cols_na_mode:
    train[c] = train[c].fillna(train[c].mode()[0])
    
for c in cols_na_mode:
    test[c] = test[c].fillna(test[c].mode()[0])

# %% [markdown]
# + 变量取值一致，没有变化：对预测没有意义，删除变量

# %%
train['Utilities'].value_counts()
# Out:
# AllPub    1457
# NoSeWa       1
# Name: Utilities, dtype: int64

# %%
train = train.drop(['Utilities'], axis=1)

test = test.drop(['Utilities'], axis=1)

# %% [markdown]
# + 删除序号

# %%
train_ID = train['Id']
test_ID = test['Id']

train = train.drop(['Id'], axis=1)
test = test.drop(['Id'], axis=1)

# %% [markdown]
# + 确保数据集中没有缺失值

# %%
train.isnull().sum().sum()

test.isnull().sum().sum()
# Out:
# 0
# 0

# %% [markdown]
# ## 合并训练集和测试集

# %% [markdown]
# 合并训练集和测试集，对其进行相同的变换

# %%
ntrain = train.shape[0]
ntest = test.shape[0]
y_train = train.SalePrice.values
all_data = pd.concat((train, test)).reset_index(drop=True)
all_data.drop(['SalePrice'], axis=1, inplace=True)
print("合并训练集和测试集后，数据集的维度是 : {}".format(all_data.shape))
# Out:
# 合并训练集和测试集后，数据集的维度是 : (2917, 78)

# %% [markdown]
# ## 对有序的离散型变量进行编码
# 对于有序的离散型变量，房屋的价格随着变量的升序而增加
# 编码方式：根据离散型变量的取值对数据集进行分组，计算组内样本的 `SalePrice` 均值，按照 `SalePrice` 均值的升序，对离散型变量进行编码

# %%
def label_encoder(train_set, all_data_set, feature):
    ordering = pd.DataFrame()
    ordering['val'] = train_set[feature].unique()
    ordering.index = ordering.val
    ordering['spmean'] = train_set[[feature, 'SalePrice']].groupby(feature).mean()['SalePrice']
    ordering = ordering.sort_values('spmean')
    ordering['ordering'] = range(1, ordering.shape[0]+1)
    ordering = ordering['ordering'].to_dict()

    all_data_set[feature] = all_data_set[feature].map(ordering)

# %%
cols = ('FireplaceQu', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond', 
        'ExterQual', 'ExterCond','HeatingQC', 'PoolQC', 'KitchenQual', 'BsmtFinType1', 
        'BsmtFinType2', 'Functional', 'Fence', 'BsmtExposure', 'GarageFinish', 'LandSlope',
        'LotShape', 'PavedDrive', 'Street', 'Alley', 'CentralAir', 'MSSubClass', 'OverallCond', 
        'YrSold', 'MoSold')

for c in cols:
    label_encoder(train, all_data, c)

# %% [markdown]
# ## 房屋总面积变量
# 房屋总面积 = 地下室总面积 + 1楼总面积 + 2楼总面积

# %%
all_data['TotalSF'] = all_data['TotalBsmtSF'] + all_data['1stFlrSF'] + all_data['2ndFlrSF']

# %% [markdown]
# ## Box-Cox 变换
# 根据前面的单变量分析可知，绝大多数连续型变量不服从正态分布，因此，对连续型变量进行Box-Cox变换，使之更接近正态分布

# %%
numeric_feats = all_data.dtypes[all_data.dtypes != "object"].index

skewness = all_data[numeric_feats].apply(lambda x: skew(x.dropna())).sort_values(ascending=False)
skewness = pd.DataFrame({'Skew' :skewness})

# %%
skewness = skewness[abs(skewness) > 0.75]
print("一共有 {} 个连续型变量需要进行Box-Cox变换".format(skewness.shape[0]))

from scipy.special import boxcox1p

skewed_features = skewness.index
lam = 0.15

for feat in skewed_features:
    all_data[feat] = boxcox1p(all_data[feat], lam)
# Out:
# 一共有 37 个连续型变量需要进行Box-Cox变换

# %% [markdown]
# ## 对无序的离散型变量进行独热编码

# %%
all_data = pd.get_dummies(all_data)

# %% [markdown]
# ## 分离训练集和测试集

# %%
train = all_data[:ntrain]
test = all_data[ntrain:]

# %% [markdown]
# # 建模

# %%
from sklearn.linear_model import ElasticNet, Lasso, BayesianRidge, LassoLarsIC
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb
import lightgbm as lgb

# %% [markdown]
# ## 交叉验证函数
# 返回5折交叉验证的 `Root-Mean-Squared-Error (RMSE)`

# %%
n_folds = 5

def rmsle_cv(model):
    kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(train.values)
    rmse= np.sqrt(-cross_val_score(model, train.values, y_train, scoring="neg_mean_squared_error", cv = kf))
    return(rmse)

# %% [markdown]
# ## 基模型

# %% [markdown]
# + Lasso

# %%
lasso = Lasso(alpha =0.0005, random_state=1)

# %%
score = rmsle_cv(lasso)
print("Lasso score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Lasso score: 0.1127 (0.0066)

# %% [markdown]
# + Elastic Net Regression

# %%
ENet = make_pipeline(RobustScaler(), ElasticNet(alpha=0.0005, l1_ratio=.9, random_state=3))

# %%
score = rmsle_cv(ENet)
print("ElasticNet score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# ElasticNet score: 0.1107 (0.0066)

# %% [markdown]
# + Kernel Ridge Regression

# %%
KRR = KernelRidge(alpha=0.6, kernel='polynomial', degree=2, coef0=2.5)

# %%
score = rmsle_cv(KRR)
print("Kernel Ridge score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Kernel Ridge score: 0.1142 (0.0063)

# %% [markdown]
# + Gradient Boosting Regression

# %%
GBoost = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber', random_state =5)

# %%
score = rmsle_cv(GBoost)
print("Gradient Boosting score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Gradient Boosting score: 0.1171 (0.0083)

# %% [markdown]
# + XGBoost

# %%
model_xgb = xgb.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468, 
                             learning_rate=0.05, max_depth=3, 
                             min_child_weight=1.7817, n_estimators=2200,
                             reg_alpha=0.4640, reg_lambda=0.8571,
                             subsample=0.5213, silent=1,
                             random_state =7, nthread = -1)

# %%
score = rmsle_cv(model_xgb)
print("Xgboost score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Xgboost score: 0.1156 (0.0066)

# %% [markdown]
# + LightGBM

# %%
model_lgb = lgb.LGBMRegressor(objective='regression',num_leaves=5,
                              learning_rate=0.05, n_estimators=720,
                              max_bin = 55, bagging_fraction = 0.8,
                              bagging_freq = 5, feature_fraction = 0.2319,
                              feature_fraction_seed=9, bagging_seed=9,
                              min_data_in_leaf =6, min_sum_hessian_in_leaf = 11)

# %%
score = rmsle_cv(model_lgb)
print("LGBM score: {:.4f} ({:.4f})\n" .format(score.mean(), score.std()))
# Out:
# LGBM score: 0.1161 (0.0073)

# %% [markdown]
# # 模型融合

# %% [markdown]
# ## 简单平均融合
# 融合方式：对基模型的预测结果取简单平均

# %%
class AveragingModels(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self, models):
        self.models = models
        
    # we define clones of the original models to fit the data in
    def fit(self, X, y):
        self.models_ = [clone(x) for x in self.models]
        
        # Train cloned base models
        for model in self.models_:
            model.fit(X, y)

        return self
    
    #Now we do the predictions for cloned models and average them
    def predict(self, X):
        predictions = np.column_stack([
            model.predict(X) for model in self.models_
        ])
        return np.mean(predictions, axis=1)

# %%
averaged_models = AveragingModels(models = (ENet, GBoost, KRR, lasso))

score = rmsle_cv(averaged_models)
print(" Averaged base models score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
#  Averaged base models score: 0.1088 (0.0067)

# %% [markdown]
# ## 堆叠模型

# %% [markdown]
# [堆叠模型介绍](https://zhuanlan.zhihu.com/p/25836678)

# %%
class StackingAveragedModels(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self, base_models, meta_model, n_folds=5):
        self.base_models = base_models
        self.meta_model = meta_model
        self.n_folds = n_folds
   
    # We again fit the data on clones of the original models
    def fit(self, X, y):
        self.base_models_ = [list() for x in self.base_models]
        self.meta_model_ = clone(self.meta_model)
        kfold = KFold(n_splits=self.n_folds, shuffle=True)
        
        # Train cloned base models then create out-of-fold predictions
        # that are needed to train the cloned meta-model
        out_of_fold_predictions = np.zeros((X.shape[0], len(self.base_models)))
        for i, model in enumerate(self.base_models):
            for train_index, holdout_index in kfold.split(X, y):
                instance = clone(model)
                self.base_models_[i].append(instance)
                instance.fit(X[train_index], y[train_index])
                y_pred = instance.predict(X[holdout_index])
                out_of_fold_predictions[holdout_index, i] = y_pred
                
        # Now train the cloned  meta-model using the out-of-fold predictions as new feature
        self.meta_model_.fit(out_of_fold_predictions, y)
        return self
   
    #Do the predictions of all base models on the test data and use the averaged predictions as 
    #meta-features for the final prediction which is done by the meta-model
    def predict(self, X):
        meta_features = np.column_stack([
            np.column_stack([model.predict(X) for model in base_models]).mean(axis=1)
            for base_models in self.base_models_ ])
        return self.meta_model_.predict(meta_features)

# %% [markdown]
# 使用 `Enet` `KRR` and `GBoost` 作为基模型，`lasso` 作为 `meta-model`
# 堆叠模型的效果相对于简单平均融合，有所提升

# %%
stacked_averaged_models = StackingAveragedModels(base_models = (ENet, GBoost, KRR),
                                                 meta_model = lasso)

score = rmsle_cv(stacked_averaged_models)
print("Stacking Averaged models score: {:.4f} ({:.4f})".format(score.mean(), score.std()))
# Out:
# Stacking Averaged models score: 0.1084 (0.0067)

# %% [markdown]
# ## 加权平均融合

# %%
stacked_averaged_models.fit(train.values, y_train)
stacked_pred = np.expm1(stacked_averaged_models.predict(test.values))

model_xgb.fit(train, y_train)
xgb_pred = np.expm1(model_xgb.predict(test))

model_lgb.fit(train, y_train)
lgb_pred = np.expm1(model_lgb.predict(test.values))

ensemble = stacked_pred*0.70 + xgb_pred*0.15 + lgb_pred*0.15
# Out:
# StackingAveragedModels(base_models=(Pipeline(steps=[('robustscaler', RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#        with_scaling=True)), ('elasticnet', ElasticNet(alpha=0.0005, copy_X=True, fit_intercept=True, l1_ratio=0.9,
#       max_iter=1000, normalize=False, positive=False, precompute=...nelRidge(alpha=0.6, coef0=2.5, degree=2, gamma=None, kernel='polynomial',
#       kernel_params=None)),
#             meta_model=Lasso(alpha=0.0005, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=1,
#    selection='cyclic', tol=0.0001, warm_start=False),
#             n_folds=5)
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.4603, gamma=0.0468, learning_rate=0.05,
#        max_delta_step=0, max_depth=3, min_child_weight=1.7817,
#        missing=None, n_estimators=2200, n_jobs=1, nthread=-1,
# ...

# %%
sub = pd.DataFrame()
sub['Id'] = test_ID
sub['SalePrice'] = ensemble
sub.to_csv('submission.csv',index=False)
